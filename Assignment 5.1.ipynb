# %%
import pandas as pd

# %%
df = pd.read_excel("Price list.xlsx")
df.columns = ['price']
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100

# %% [markdown]
# # Normalization

# %%
min_price = df.price.min()
max_price = df.price.max()

# %%
min_price
# Out:
# 100

# %%
max_price
# Out:
# 150

# %%
df['price_norm_manual'] = (df.price - min_price) / (max_price - min_price)

# %%
df
# Out:
#    price  price_norm_manual
# 0    110                0.2
# 1    105                0.1
# 2    115                0.3
# 3    120                0.4
# 4    110                0.2
# 5    130                0.6
# 6    150                1.0
# 7    100                0.0

# %%
from sklearn.preprocessing import MinMaxScaler
nmx = MinMaxScaler()

# %%
df['price_norm_sklearn'] = nmx.fit_transform(df[['price']])

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn
# 0    110                0.2                 0.2
# 1    105                0.1                 0.1
# 2    115                0.3                 0.3
# 3    120                0.4                 0.4
# 4    110                0.2                 0.2
# 5    130                0.6                 0.6
# 6    150                1.0                 1.0
# 7    100                0.0                 0.0

# %% [markdown]
# # STANDARDIZATION

# %%
mean_price = df.price.mean()
std = df.price.std()

# %%
df['price_std_manual'] = (df['price'] - mean_price) / std

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual
# 0    110                0.2                 0.2         -0.467707
# 1    105                0.1                 0.1         -0.779512
# 2    115                0.3                 0.3         -0.155902
# 3    120                0.4                 0.4          0.155902
# 4    110                0.2                 0.2         -0.467707
# 5    130                0.6                 0.6          0.779512
# 6    150                1.0                 1.0          2.026731
# 7    100                0.0                 0.0         -1.091317

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df['price_std_sklearn'] = scaler.fit_transform(df[['price']])

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.467707
# 1    105                0.1                 0.1         -0.779512
# 2    115                0.3                 0.3         -0.155902
# 3    120                0.4                 0.4          0.155902
# 4    110                0.2                 0.2         -0.467707
# 5    130                0.6                 0.6          0.779512
# 6    150                1.0                 1.0          2.026731
# 7    100                0.0                 0.0         -1.091317
#
#    price_std_sklearn
# 0          -0.500000
# 1          -0.833333
# 2          -0.166667
# 3           0.166667
# 4          -0.500000
# 5           0.833333
# 6           2.166667
# 7          -1.166667

# %% [markdown]
# # Log Transformation

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np

# %%
fc = FunctionTransformer(np.log1p)
df['price_fc'] = fc.fit_transform(df[['price']])

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.467707
# 1    105                0.1                 0.1         -0.779512
# 2    115                0.3                 0.3         -0.155902
# 3    120                0.4                 0.4          0.155902
# 4    110                0.2                 0.2         -0.467707
# 5    130                0.6                 0.6          0.779512
# 6    150                1.0                 1.0          2.026731
# 7    100                0.0                 0.0         -1.091317
#
#    price_std_sklearn
# 0          -0.500000
# 1          -0.833333
# 2          -0.166667
# 3           0.166667
# 4          -0.500000
# 5           0.833333
# 6           2.166667
# 7          -1.166667

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mx = MaxAbsScaler()

# %%
df['mx_abs'] = mx.fit_transform(df[['price']])

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.467707
# 1    105                0.1                 0.1         -0.779512
# 2    115                0.3                 0.3         -0.155902
# 3    120                0.4                 0.4          0.155902
# 4    110                0.2                 0.2         -0.467707
# 5    130                0.6                 0.6          0.779512
# 6    150                1.0                 1.0          2.026731
# 7    100                0.0                 0.0         -1.091317
#
#    price_std_sklearn  price_fc    mx_abs
# 0          -0.500000  4.709530  0.733333
# 1          -0.833333  4.663439  0.700000
# 2          -0.166667  4.753590  0.766667
# 3           0.166667  4.795791  0.800000
# 4          -0.500000  4.709530  0.733333
# 5           0.833333  4.875197  0.866667
# 6           2.166667  5.017280  1.000000
# 7          -1.166667  4.615121  0.666667

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()

# %%
df['rs'] = scaler.fit_transform(df[['price']])

# %%
df
# Out:
#    price  price_norm_manual  price_norm_sklearn  price_std_manual  \
# 0    110                0.2                 0.2         -0.467707
# 1    105                0.1                 0.1         -0.779512
# 2    115                0.3                 0.3         -0.155902
# 3    120                0.4                 0.4          0.155902
# 4    110                0.2                 0.2         -0.467707
# 5    130                0.6                 0.6          0.779512
# 6    150                1.0                 1.0          2.026731
# 7    100                0.0                 0.0         -1.091317
#
#    price_std_sklearn  price_fc    mx_abs        rs
# 0          -0.500000  4.709530  0.733333 -0.500000
# 1          -0.833333  4.663439  0.700000 -0.833333
# 2          -0.166667  4.753590  0.766667 -0.166667
# 3           0.166667  4.795791  0.800000  0.166667
# 4          -0.500000  4.709530  0.733333 -0.500000
# 5           0.833333  4.875197  0.866667  0.833333
# 6           2.166667  5.017280  1.000000  2.166667
# 7          -1.166667  4.615121  0.666667 -1.166667
